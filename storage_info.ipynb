# %%
import pickle

# %%
with open(r'blocked_db', 'rb') as fp:
    s = pickle.load(fp)
s
# Out:
# array([-1.04957357e-01,  4.45798971e-03,  7.26529434e-02, -6.77670911e-02,
#        -1.03489302e-01, -8.26164484e-02, -7.14479461e-02, -2.79787369e-02,
#         2.04907432e-01, -1.55074090e-01,  1.68816671e-01, -3.19339596e-02,
#        -1.47668421e-01, -2.81840339e-02, -6.10317662e-02,  2.13658303e-01,
#        -1.58115655e-01, -9.01004300e-02, -3.45814973e-02, -5.97555786e-02,
#         4.88394275e-02,  3.16931792e-02, -2.48545920e-03,  7.21120536e-02,
#        -1.04335770e-01, -4.11012560e-01, -7.68422931e-02, -9.36791524e-02,
#        -3.26276533e-02, -7.60329189e-03, -4.84060124e-03,  1.62722498e-01,
#        -1.11959867e-01, -2.42070276e-02,  3.32756117e-02,  9.92844999e-02,
#        -2.79112570e-02, -1.08652553e-02,  2.27409378e-01,  6.03742711e-03,
#        -2.74059206e-01, -6.09224848e-02,  1.21464223e-01,  2.45168313e-01,
#         1.86737120e-01,  9.83737707e-02,  6.33626804e-02, -3.87459472e-02,
# ...

# %%
import sys
sys.getsizeof(s)
# Out:
# 112

# %%
s.shape
# Out:
# (128,)
